# %% [markdown]
# Create local Client

# %%
from dask.distributed import Client
client = Client()
client
# Out:
# C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 63255 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:63259' processes=4 threads=8, memory=7.89 GiB>
# Task exception was never retrieved
# future: <Task finished name='Task-2939488' coro=<Client._gather.<locals>.wait() done, defined at C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py:2377> exception=AllExit()>
# Traceback (most recent call last):
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py", line 2386, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-2939494' coro=<Client._gather.<locals>.wait() done, defined at C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py:2377> exception=AllExit()>
# Traceback (most recent call last):
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py", line 2386, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-2939487' coro=<Client._gather.<locals>.wait() done, defined at C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py:2377> exception=AllExit()>
# Traceback (most recent call last):
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py", line 2386, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-2939492' coro=<Client._gather.<locals>.wait() done, defined at C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py:2377> exception=AllExit()>
# Traceback (most recent call last):
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py", line 2386, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-2939495' coro=<Client._gather.<locals>.wait() done, defined at C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py:2377> exception=AllExit()>
# Traceback (most recent call last):
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py", line 2386, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-2939490' coro=<Client._gather.<locals>.wait() done, defined at C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py:2377> exception=AllExit()>
# Traceback (most recent call last):
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py", line 2386, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-2939486' coro=<Client._gather.<locals>.wait() done, defined at C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py:2377> exception=AllExit()>
# Traceback (most recent call last):
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py", line 2386, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-2939482' coro=<Client._gather.<locals>.wait() done, defined at C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py:2377> exception=AllExit()>
# Traceback (most recent call last):
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py", line 2386, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-3157806' coro=<Client._gather.<locals>.wait() done, defined at C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py:2377> exception=AllExit()>
# Traceback (most recent call last):
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py", line 2386, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-3157802' coro=<Client._gather.<locals>.wait() done, defined at C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py:2377> exception=AllExit()>
# Traceback (most recent call last):
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py", line 2386, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-3157796' coro=<Client._gather.<locals>.wait() done, defined at C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py:2377> exception=AllExit()>
# Traceback (most recent call last):
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py", line 2386, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-3157804' coro=<Client._gather.<locals>.wait() done, defined at C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py:2377> exception=AllExit()>
# Traceback (most recent call last):
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py", line 2386, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-3157810' coro=<Client._gather.<locals>.wait() done, defined at C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py:2377> exception=AllExit()>
# Traceback (most recent call last):
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py", line 2386, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-3157803' coro=<Client._gather.<locals>.wait() done, defined at C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py:2377> exception=AllExit()>
# Traceback (most recent call last):
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py", line 2386, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-3157799' coro=<Client._gather.<locals>.wait() done, defined at C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py:2377> exception=AllExit()>
# Traceback (most recent call last):
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py", line 2386, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-3157809' coro=<Client._gather.<locals>.wait() done, defined at C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py:2377> exception=AllExit()>
# Traceback (most recent call last):
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py", line 2386, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-3157805' coro=<Client._gather.<locals>.wait() done, defined at C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py:2377> exception=AllExit()>
# Traceback (most recent call last):
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py", line 2386, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-3157801' coro=<Client._gather.<locals>.wait() done, defined at C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py:2377> exception=AllExit()>
# Traceback (most recent call last):
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py", line 2386, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-3157811' coro=<Client._gather.<locals>.wait() done, defined at C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py:2377> exception=AllExit()>
# Traceback (most recent call last):
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py", line 2386, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-3157807' coro=<Client._gather.<locals>.wait() done, defined at C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py:2377> exception=AllExit()>
# Traceback (most recent call last):
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py", line 2386, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-3157800' coro=<Client._gather.<locals>.wait() done, defined at C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py:2377> exception=AllExit()>
# Traceback (most recent call last):
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py", line 2386, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-3157797' coro=<Client._gather.<locals>.wait() done, defined at C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py:2377> exception=AllExit()>
# Traceback (most recent call last):
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\client.py", line 2386, in wait
#     raise AllExit()
# distributed.client.AllExit
# 2025-06-27 08:58:04,036 - distributed.scheduler - WARNING - Worker failed to heartbeat for 45585s; attempting restart: <WorkerState 'tcp://127.0.0.1:63279', name: 2, status: running, memory: 0, processing: 0>
# 2025-06-27 08:58:04,083 - distributed.scheduler - WARNING - Worker failed to heartbeat for 45585s; attempting restart: <WorkerState 'tcp://127.0.0.1:63280', name: 1, status: running, memory: 0, processing: 0>
# 2025-06-27 08:58:04,631 - distributed.scheduler - WARNING - Worker failed to heartbeat for 45585s; attempting restart: <WorkerState 'tcp://127.0.0.1:63281', name: 3, status: running, memory: 0, processing: 0>
# 2025-06-27 08:58:05,738 - distributed.scheduler - WARNING - Worker failed to heartbeat for 45585s; attempting restart: <WorkerState 'tcp://127.0.0.1:63288', name: 0, status: running, memory: 0, processing: 0>
# 2025-06-27 08:58:20,620 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-06-27 08:58:22,421 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-06-27 08:58:22,421 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-06-27 08:58:22,437 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-06-27 08:58:24,571 - distributed.core - ERROR - Exception while handling op kill
# Traceback (most recent call last):
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\utils.py", line 1923, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\core.py", line 834, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\nanny.py", line 400, in kill
#     await self.process.kill(reason=reason, timeout=timeout)
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\nanny.py", line 883, in kill
#     await process.join(max(0, deadline - time()))
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\process.py", line 330, in join
#     await wait_for(asyncio.shield(self._exit_future), timeout)
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\utils.py", line 1922, in wait_for
#     async with asyncio.timeout(timeout):
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\asyncio\timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# 2025-06-27 08:58:24,740 - distributed.core - ERROR - Exception while handling op kill
# Traceback (most recent call last):
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\utils.py", line 1923, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\core.py", line 834, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\nanny.py", line 400, in kill
#     await self.process.kill(reason=reason, timeout=timeout)
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\nanny.py", line 883, in kill
#     await process.join(max(0, deadline - time()))
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\process.py", line 330, in join
#     await wait_for(asyncio.shield(self._exit_future), timeout)
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\utils.py", line 1922, in wait_for
#     async with asyncio.timeout(timeout):
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\asyncio\timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# 2025-06-27 08:58:24,971 - distributed.core - ERROR - Exception while handling op kill
# Traceback (most recent call last):
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\utils.py", line 1923, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\core.py", line 834, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\nanny.py", line 400, in kill
#     await self.process.kill(reason=reason, timeout=timeout)
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\nanny.py", line 883, in kill
#     await process.join(max(0, deadline - time()))
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\process.py", line 330, in join
#     await wait_for(asyncio.shield(self._exit_future), timeout)
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\utils.py", line 1922, in wait_for
#     async with asyncio.timeout(timeout):
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\asyncio\timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# 2025-06-27 08:58:25,402 - distributed.core - ERROR - Exception while handling op kill
# Traceback (most recent call last):
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\utils.py", line 1923, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\core.py", line 834, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\nanny.py", line 400, in kill
#     await self.process.kill(reason=reason, timeout=timeout)
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\nanny.py", line 883, in kill
#     await process.join(max(0, deadline - time()))
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\process.py", line 330, in join
#     await wait_for(asyncio.shield(self._exit_future), timeout)
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\utils.py", line 1922, in wait_for
#     async with asyncio.timeout(timeout):
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\asyncio\timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# 2025-06-27 08:58:26,866 - distributed.scheduler - ERROR - Workers ['tcp://127.0.0.1:63280', 'tcp://127.0.0.1:63279', 'tcp://127.0.0.1:63281', 'tcp://127.0.0.1:63288'] did not shut down within 30s; force closing
# 2025-06-27 08:58:27,513 - distributed.scheduler - ERROR - 4/4 nanny worker(s) did not shut down within 30s: {'tcp://127.0.0.1:63280', 'tcp://127.0.0.1:63279', 'tcp://127.0.0.1:63281', 'tcp://127.0.0.1:63288'}
# Traceback (most recent call last):
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\utils.py", line 818, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\scheduler.py", line 6666, in restart_workers
#     raise TimeoutError(
# TimeoutError: 4/4 nanny worker(s) did not shut down within 30s: {'tcp://127.0.0.1:63280', 'tcp://127.0.0.1:63279', 'tcp://127.0.0.1:63281', 'tcp://127.0.0.1:63288'}
# 2025-06-27 08:58:27,551 - distributed.scheduler - ERROR - 4/4 nanny worker(s) did not shut down within 30s: {'tcp://127.0.0.1:63280', 'tcp://127.0.0.1:63279', 'tcp://127.0.0.1:63281', 'tcp://127.0.0.1:63288'}
# Traceback (most recent call last):
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\utils.py", line 818, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\scheduler.py", line 8724, in check_worker_ttl
#     await self.restart_workers(
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\utils.py", line 818, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\scheduler.py", line 6666, in restart_workers
#     raise TimeoutError(
# TimeoutError: 4/4 nanny worker(s) did not shut down within 30s: {'tcp://127.0.0.1:63280', 'tcp://127.0.0.1:63279', 'tcp://127.0.0.1:63281', 'tcp://127.0.0.1:63288'}
# 2025-06-27 08:58:27,567 - tornado.application - ERROR - Exception in callback <bound method Scheduler.check_worker_ttl of <Scheduler 'tcp://127.0.0.1:63259', workers: 0, cores: 0, tasks: 0>>
# Traceback (most recent call last):
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\tornado\ioloop.py", line 939, in _run
#     await val
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\utils.py", line 818, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\scheduler.py", line 8724, in check_worker_ttl
#     await self.restart_workers(
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\utils.py", line 818, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\eleme\.conda\envs\teamx\Lib\site-packages\distributed\scheduler.py", line 6666, in restart_workers
#     raise TimeoutError(
# TimeoutError: 4/4 nanny worker(s) did not shut down within 30s: {'tcp://127.0.0.1:63280', 'tcp://127.0.0.1:63279', 'tcp://127.0.0.1:63281', 'tcp://127.0.0.1:63288'}
# 2025-06-27 08:58:32,695 - distributed.nanny - WARNING - Restarting worker
# 2025-06-27 08:58:32,758 - distributed.nanny - WARNING - Restarting worker
# 2025-06-27 08:58:32,758 - distributed.nanny - WARNING - Restarting worker
# 2025-06-27 08:58:32,795 - distributed.nanny - WARNING - Restarting worker

# %%
client = Client('127.0.0.1:50211')

# %%
import sys
from operator import concat

from xarray import decode_cf

sys.path.append("D:/MSc_Arbeit/model_comparison_codes")
import confg
import xarray as xr
import numpy as np
from functools import partial
import metpy.calc as mpcalc
from metpy.units import units
import datetime
from pathlib import Path
import read_icon_model_3D

# %%
lat_ibk = 47.259998
lon_ibk = 11.384167

# %% [markdown]
# with h5py.File('ICON2TE_20171015_latlon.nc', 'r') as f:
#     for var in f:
#         dset = f[var]
#         if hasattr(dset, 'chunks') and dset.chunks is not None:
#             print(f"{var}: {dset.chunks}")

# %% [markdown]
# %%time
# icon_10 = xr.open_dataset(confg.icon_folder_3D + "/ICON_20171015_latlon.nc")
# #
# # icon_point = icon_point.compute()

# %%
def convert_calc_variables(ds):
    """
    Converts and calculates meteorological variables for a xarray Dataset.

    Parameters:
    - df: A xarray Dataset containing the columns 'p' for pressure in Pa
          and 'th' for potential temperature in Kelvin.

    Returns:
    - A xarray Dataset with the original data and new columns:
      'pressure' in hPa and 'temperature' in degrees Celsius.
    """

    # Convert pressure from Pa to hPa
    ds['pressure'] = (ds['pres'] / 100.0) * units.hPa

    # calc pot temp
    ds["th"] = mpcalc.potential_temperature(ds['pressure'], ds["temp"] * units.kelvin)

    # convert temp to °C
    ds["temp"]  = (ds["temp"] - 273.15) * units.degC

    return ds.metpy.dequantify()  # remove units from the dataset

# %%
#chunksizes = (1, 90, 712, 1097)
def read_icon_fixed_point(lat, lon, variant="ICON"):
    if variant == "ICON":
        icon_full = xr.open_dataset(confg.icon_folder_3D + "/ICON_20171015_latlon.nc", chunks="auto")  # , chunks={lat': 10, 'lon': 10}

    elif variant == "ICON2TE":
        icon_full = xr.open_dataset(confg.icon2TE_folder_3D + "/ICON2TE_20171015_latlon.nc", chunks={'lat': 10, 'lon': 10})

    icon_point = icon_full.sel(lat=lat, lon=lon, method="nearest")
    icon_point = convert_calc_variables(icon_point)
    icon_point = icon_point.rename({"z_ifc": "z"})
    icon_point = icon_point.compute()
    return icon_point

# %%
# %time
read_icon_fixed_point(lat=lat_ibk, lon=lon_ibk, variant="ICON")
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
# %timeit
icon_full = xr.open_dataset(confg.icon_folder_3D + "/ICON_latlon_subset_tirol.nc", chunks={'lat': 2, 'lon': 2})
icon_point = icon_full.sel(lat=lat_ibk, lon=lon_ibk, method="nearest")
icon_point = convert_calc_variables(icon_point)
icon_point = icon_point.rename({"z_ifc": "z"})
icon_point = icon_point.compute()

# %%
# %%time
icon_point = icon_full.sel(lat=lat_ibk, lon=lon_ibk, method="nearest")
# Out:
# CPU times: total: 0 ns
# Wall time: 24.2 ms

# %%
# %%time
icon_point = icon_point.sel(lat=lat_ibk, lon=lon_ibk, method="nearest")
# Out:
# CPU times: total: 15.6 ms
# Wall time: 25.6 ms

# %%
# %%time
icon_calc = convert_calc_variables(icon_point)
# Out:
# CPU times: total: 31.2 ms
# Wall time: 36 ms

# %%
# %%time
icon_point_100 = icon_calc.compute()  # takes insanely long! >300s!
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:1
#
# File ~\.conda\envs\teamx\Lib\site-packages\xarray\core\dataset.py:767, in Dataset.compute(self, **kwargs)
#     743 """Manually trigger loading and/or computation of this dataset's data
#     744 from disk or a remote source into memory and return a new dataset.
#     745 Unlike load, the original dataset is left unaltered.
#    (...)    764 dask.compute
#     765 """
#     766 new = self.copy(deep=False)
# --> 767 return new.load(**kwargs)
#
# File ~\.conda\envs\teamx\Lib\site-packages\xarray\core\dataset.py:594, in Dataset.load(self, **kwargs)
#     591 chunkmanager = get_chunked_array_type(*lazy_data.values())
#     593 # evaluate all the chunked arrays simultaneously
# --> 594 evaluated_data: tuple[np.ndarray[Any, Any], ...] = chunkmanager.compute(
#     595     *lazy_data.values(), **kwargs
#     596 )
#     598 for k, data in zip(lazy_data, evaluated_data, strict=False):
#     599     self.variables[k].data = data
#
# File ~\.conda\envs\teamx\Lib\site-packages\xarray\namedarray\daskmanager.py:85, in DaskManager.compute(self, *data, **kwargs)
#      80 def compute(
#      81     self, *data: Any, **kwargs: Any
#      82 ) -> tuple[np.ndarray[Any, _DType_co], ...]:
#      83     from dask.array import compute
# ---> 85     return compute(*data, **kwargs)
#
# File ~\.conda\envs\teamx\Lib\site-packages\dask\base.py:681, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     678     expr = expr.optimize()
#     679     keys = list(flatten(expr.__dask_keys__()))
# --> 681     results = schedule(expr, keys, **kwargs)
#     683 return repack(results)
#
# File ~\.conda\envs\teamx\Lib\queue.py:180, in Queue.get(self, block, timeout)
#     178         if remaining <= 0.0:
#     179             raise Empty
# --> 180         self.not_empty.wait(remaining)
#     181 item = self._get()
#     182 self.not_full.notify()
#
# File ~\.conda\envs\teamx\Lib\threading.py:331, in Condition.wait(self, timeout)
#     329 else:
#     330     if timeout > 0:
# --> 331         gotit = waiter.acquire(True, timeout)
#     332     else:
#     333         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# ## icon fixed time

# %% [markdown]
# icon_fixed_time = read_icon_model_3D.read_icon_fixed_time(day=16, hour=12, min=0, variant="ICON")

# %%
def read_icon_fixed_time(day=16, hour=12, min=0, variant="ICON"):
    if variant == "ICON":
        icon_full = xr.open_dataset(confg.icon_folder_3D + "/ICON_20171015_latlon.nc",
                                    chunks={'time': 10})
    elif variant == "ICON_2TE":
        icon_full = xr.open_dataset(confg.icon2TE_folder_3D + "/ICON2TE_20171015_latlon.nc",
                                    chunks={'time': 10})
    timestamp = datetime.datetime(2017, 10, day, hour, min, 00)
    icon_point = icon_full.sel(time=timestamp, height=90, method="nearest")
    icon_point = convert_calc_variables(icon_point)
    icon_point = icon_point.compute()
    return icon_point

# %%
# %%time
icon_extent = read_icon_fixed_time(day=16, hour=12, min=0, variant="ICON2TE")
icon_extent
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# File <timed exec>:1
#
# Cell In[54], line 9, in read_icon_fixed_time(day, hour, min, variant)
#       6     icon_full = xr.open_dataset(confg.icon2TE_folder_3D + "/ICON2TE_20171015_latlon.nc",
#       7                                 chunks={'time': 10})
#       8 timestamp = datetime.datetime(2017, 10, day, hour, min, 00)
# ----> 9 icon_point = icon_full.sel(time=timestamp, height=90, method="nearest")
#      10 icon_point = convert_calc_variables(icon_point)
#      11 icon_point = icon_point.compute()
#
# UnboundLocalError: cannot access local variable 'icon_full' where it is not associated with a value

# %%
# %%time
import dask.array as da
x = da.random.random((10000, 10000, 10), chunks=(1000, 1000, 5))
y = da.random.random((10000, 10000, 10), chunks=(1000, 1000, 5))
z = (da.arcsin(x) + da.arccos(y)).sum(axis=(1, 2))
z.persist()
# Out:
# CPU times: total: 141 ms
# Wall time: 270 ms
# dask.array<sum-aggregate, shape=(10000,), dtype=float64, chunksize=(1000,), chunktype=numpy.ndarray>
