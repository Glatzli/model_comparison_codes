# %%
# %run D:\codes\confg
# %run D:\codes\ukmo\read_ukmo.ipynb
# %run D:/codes/icon/read_icon_model_3D.ipynb
# %run D:/codes/icon/read_icon2TE_model_3D.ipynb
# %run D:/codes/wrf_helen/wrf_zeitreihe.ipynb
# %run D:/codes/icon/icons_zeitreihe.ipynb
# %run D:/codes/HATPRO/zeitreihe_hatpro.ipynb
# %run D:/codes/HOBOs/hobos_read_in.ipynb
# %run D:/codes/icon/icons_zeitreihe-Copy1.ipynb

# %%
# %%capture
import warnings
import glob
import os
import pandas as pd
import xarray as xr
import metpy
import metpy.calc as mpcalc
import numpy as np
import pandas as pd
import wrf
from matplotlib import pyplot as plt
from metpy.units import units
from netCDF4 import Dataset
    
warnings.filterwarnings("ignore")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# D:/codes/wrf_helen/wrf_zeitreihe.ipynb in <module>
# ----> 1 wrf = read_radiosonde_wrf_acinn()
#
# D:/codes/wrf_helen/wrf_zeitreihe.ipynb in read_radiosonde_wrf_acinn()
#      23
#      24                 # Read data for each fixed point and time
# ---> 25                 df_acinn15 = read_wrf_fixed_point_and_time(
#      26                     day=day,
#      27                     hour=hour,
#
# D:/codes/wrf_helen/wrf_zeitreihe.ipynb in read_wrf_fixed_point_and_time(day, hour, latitude, longitude, minute)
#      35                          crs='epsg:4236')
#      36     df = df.isel(Time=0, south_north=0, west_east=0)  # select all isel =0
# ---> 37     df = convert_calc_variables(df)
#      38
#      39     return df
#
# D:/codes/wrf_helen/wrf_zeitreihe.ipynb in convert_calc_variables(df_wrf, selected_vars)
#      23     for var in selected_vars:
#      24         if var in df_wrf and 'units' in df_wrf[var].attrs and df_wrf[var].attrs['units'] not in ['-', '', None]:
# ---> 25             df_quantified[var] = df_wrf[var].metpy.quantify()
#      26         else:
#      27             print(f"Variable '{var}' does not have valid units and will not be quantified.")
#
# ~\anaconda3\envs\myenv\lib\site-packages\metpy\xarray.py in quantify(self)
#     229         """
#     230         if (
# --> 231             not is_quantity(self._data_array.data)
#     232             and np.issubdtype(self._data_array.data.dtype, np.number)
#     233         ):
#
# ~\anaconda3\envs\myenv\lib\site-packages\xarray\core\dataarray.py in data(self)
#     780         DataArray.values
#     781         """
# --> 782         return self.variable.data
#     783
#     784     @data.setter
#
# ~\anaconda3\envs\myenv\lib\site-packages\xarray\core\variable.py in data(self)
#     447             return self._data
#     448         elif isinstance(self._data, indexing.ExplicitlyIndexed):
# --> 449             return self._data.get_duck_array()
#     450         else:
#     451             return self.values
#
# ~\anaconda3\envs\myenv\lib\site-packages\xarray\core\indexing.py in get_duck_array(self)
#     835
#     836     def get_duck_array(self):
# --> 837         self._ensure_cached()
#     838         return self.array.get_duck_array()
#     839
#
# ~\anaconda3\envs\myenv\lib\site-packages\xarray\core\indexing.py in _ensure_cached(self)
#     829
#     830     def _ensure_cached(self):
# --> 831         self.array = as_indexable(self.array.get_duck_array())
#     832
#     833     def __array__(self, dtype: np.typing.DTypeLike = None) -> np.ndarray:
#
# ~\anaconda3\envs\myenv\lib\site-packages\xarray\core\indexing.py in get_duck_array(self)
#     786
#     787     def get_duck_array(self):
# --> 788         return self.array.get_duck_array()
#     789
#     790     def _oindex_get(self, indexer: OuterIndexer):
#
# ~\anaconda3\envs\myenv\lib\site-packages\xarray\core\indexing.py in get_duck_array(self)
#     656         # so we need the explicit check for ExplicitlyIndexed
#     657         if isinstance(array, ExplicitlyIndexed):
# --> 658             array = array.get_duck_array()
#     659         return _wrap_numpy_scalars(array)
#     660
#
# ~\anaconda3\envs\myenv\lib\site-packages\xarray\coding\variables.py in get_duck_array(self)
#      79
#      80     def get_duck_array(self):
# ---> 81         return self.func(self.array.get_duck_array())
#      82
#      83     def __repr__(self) -> str:
#
# ~\anaconda3\envs\myenv\lib\site-packages\xarray\core\indexing.py in get_duck_array(self)
#     649             # If the array is not an ExplicitlyIndexedNDArrayMixin,
#     650             # it may wrap a BackendArray so use its __getitem__
# --> 651             array = self.array[self.key]
#     652
#     653         # self.array[self.key] is now a numpy array when
#
# ~\anaconda3\envs\myenv\lib\site-packages\xarray\backends\netCDF4_.py in __getitem__(self, key)
#      98
#      99     def __getitem__(self, key):
# --> 100         return indexing.explicit_indexing_adapter(
#     101             key, self.shape, indexing.IndexingSupport.OUTER, self._getitem
#     102         )
#
# ~\anaconda3\envs\myenv\lib\site-packages\xarray\core\indexing.py in explicit_indexing_adapter(key, shape, indexing_support, raw_indexing_method)
#    1013     """
#    1014     raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# -> 1015     result = raw_indexing_method(raw_key.tuple)
#    1016     if numpy_indices.tuple:
#    1017         # index the loaded np.ndarray
#
# ~\anaconda3\envs\myenv\lib\site-packages\xarray\backends\netCDF4_.py in _getitem(self, key)
#     111             with self.datastore.lock:
#     112                 original_array = self.get_array(needs_lock=False)
# --> 113                 array = getitem(original_array, key)
#     114         except IndexError:
#     115             # Catch IndexError in netCDF4 and return a more informative
#
# src\netCDF4\_netCDF4.pyx in netCDF4._netCDF4.Variable.__getitem__()
#
# src\netCDF4\_netCDF4.pyx in netCDF4._netCDF4.Variable._get()
#
# src\netCDF4\_netCDF4.pyx in netCDF4._netCDF4._ensure_nc_success()
#
# RuntimeError: NetCDF: HDF error
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17828\1814057072.py in <module>
#      18 get_ipython().run_line_magic('run', 'D:/codes/icon/read_icon_model_3D.ipynb')
#      19 get_ipython().run_line_magic('run', 'D:/codes/icon/read_icon2TE_model_3D.ipynb')
# ---> 20 get_ipython().run_line_magic('run', 'D:/codes/wrf_helen/wrf_zeitreihe.ipynb')
#      21 get_ipython().run_line_magic('run', 'D:/codes/icon/icons_zeitreihe.ipynb')
#      22 get_ipython().run_line_magic('run', 'D:/codes/HATPRO/zeitreihe_hatpro.ipynb')
#
# ~\anaconda3\envs\myenv\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2362                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2363             with self.builtin_trap:
# -> 2364                 result = fn(*args, **kwargs)
#    2365             return result
#    2366
#
# ~\anaconda3\envs\myenv\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~\anaconda3\envs\myenv\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\envs\myenv\lib\site-packages\IPython\core\magics\execution.py in run(self, parameter_s, runner, file_finder)
#     733             with preserve_keys(self.shell.user_ns, '__file__'):
#     734                 self.shell.user_ns['__file__'] = filename
# --> 735                 self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     736             return
#     737
#
# ~\anaconda3\envs\myenv\lib\site-packages\IPython\core\interactiveshell.py in safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2849                     result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2850                     if raise_exceptions:
# -> 2851                         result.raise_error()
#    2852                     elif not result.success:
#    2853                         break
#
# ~\anaconda3\envs\myenv\lib\site-packages\IPython\core\interactiveshell.py in raise_error(self)
#     330             raise self.error_before_exec
#     331         if self.error_in_exec is not None:
# --> 332             raise self.error_in_exec
#     333
#     334     def __repr__(self):
#
#     [... skipping hidden 1 frame]
#
# ~\AppData\Local\Temp\ipykernel_17828\806160176.py in <module>
# ----> 1 wrf = read_radiosonde_wrf_acinn()
#
# ~\AppData\Local\Temp\ipykernel_17828\3392013890.py in read_radiosonde_wrf_acinn()
#      23
#      24                 # Read data for each fixed point and time
# ---> 25                 df_acinn15 = read_wrf_fixed_point_and_time(
#      26                     day=day,
#      27                     hour=hour,
#
# ~\AppData\Local\Temp\ipykernel_17828\544685370.py in read_wrf_fixed_point_and_time(day, hour, latitude, longitude, minute)
#      35                          crs='epsg:4236')
#      36     df = df.isel(Time=0, south_north=0, west_east=0)  # select all isel =0
# ---> 37     df = convert_calc_variables(df)
#      38
#      39     return df
#
# ~\AppData\Local\Temp\ipykernel_17828\955302404.py in convert_calc_variables(df_wrf, selected_vars)
#      23     for var in selected_vars:
#      24         if var in df_wrf and 'units' in df_wrf[var].attrs and df_wrf[var].attrs['units'] not in ['-', '', None]:
# ---> 25             df_quantified[var] = df_wrf[var].metpy.quantify()
#      26         else:
#      27             print(f"Variable '{var}' does not have valid units and will not be quantified.")
#
# ~\anaconda3\envs\myenv\lib\site-packages\metpy\xarray.py in quantify(self)
#     229         """
#     230         if (
# --> 231             not is_quantity(self._data_array.data)
#     232             and np.issubdtype(self._data_array.data.dtype, np.number)
#     233         ):
#
# ~\anaconda3\envs\myenv\lib\site-packages\xarray\core\dataarray.py in data(self)
#     780         DataArray.values
#     781         """
# --> 782         return self.variable.data
#     783
#     784     @data.setter
#
# ~\anaconda3\envs\myenv\lib\site-packages\xarray\core\variable.py in data(self)
#     447             return self._data
#     448         elif isinstance(self._data, indexing.ExplicitlyIndexed):
# --> 449             return self._data.get_duck_array()
#     450         else:
#     451             return self.values
#
# ~\anaconda3\envs\myenv\lib\site-packages\xarray\core\indexing.py in get_duck_array(self)
#     835
#     836     def get_duck_array(self):
# --> 837         self._ensure_cached()
#     838         return self.array.get_duck_array()
#     839
#
# ~\anaconda3\envs\myenv\lib\site-packages\xarray\core\indexing.py in _ensure_cached(self)
#     829
#     830     def _ensure_cached(self):
# --> 831         self.array = as_indexable(self.array.get_duck_array())
#     832
#     833     def __array__(self, dtype: np.typing.DTypeLike = None) -> np.ndarray:
#
# ~\anaconda3\envs\myenv\lib\site-packages\xarray\core\indexing.py in get_duck_array(self)
#     786
#     787     def get_duck_array(self):
# --> 788         return self.array.get_duck_array()
#     789
#     790     def _oindex_get(self, indexer: OuterIndexer):
#
# ~\anaconda3\envs\myenv\lib\site-packages\xarray\core\indexing.py in get_duck_array(self)
#     656         # so we need the explicit check for ExplicitlyIndexed
#     657         if isinstance(array, ExplicitlyIndexed):
# --> 658             array = array.get_duck_array()
#     659         return _wrap_numpy_scalars(array)
#     660
#
# ~\anaconda3\envs\myenv\lib\site-packages\xarray\coding\variables.py in get_duck_array(self)
#      79
#      80     def get_duck_array(self):
# ---> 81         return self.func(self.array.get_duck_array())
#      82
#      83     def __repr__(self) -> str:
#
# ~\anaconda3\envs\myenv\lib\site-packages\xarray\core\indexing.py in get_duck_array(self)
#     649             # If the array is not an ExplicitlyIndexedNDArrayMixin,
#     650             # it may wrap a BackendArray so use its __getitem__
# --> 651             array = self.array[self.key]
#     652
#     653         # self.array[self.key] is now a numpy array when
#
# ~\anaconda3\envs\myenv\lib\site-packages\xarray\backends\netCDF4_.py in __getitem__(self, key)
#      98
#      99     def __getitem__(self, key):
# --> 100         return indexing.explicit_indexing_adapter(
#     101             key, self.shape, indexing.IndexingSupport.OUTER, self._getitem
#     102         )
#
# ~\anaconda3\envs\myenv\lib\site-packages\xarray\core\indexing.py in explicit_indexing_adapter(key, shape, indexing_support, raw_indexing_method)
#    1013     """
#    1014     raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# -> 1015     result = raw_indexing_method(raw_key.tuple)
#    1016     if numpy_indices.tuple:
#    1017         # index the loaded np.ndarray
#
# ~\anaconda3\envs\myenv\lib\site-packages\xarray\backends\netCDF4_.py in _getitem(self, key)
#     111             with self.datastore.lock:
#     112                 original_array = self.get_array(needs_lock=False)
# --> 113                 array = getitem(original_array, key)
#     114         except IndexError:
#     115             # Catch IndexError in netCDF4 and return a more informative
#
# src\netCDF4\_netCDF4.pyx in netCDF4._netCDF4.Variable.__getitem__()
#
# src\netCDF4\_netCDF4.pyx in netCDF4._netCDF4.Variable._get()
#
# src\netCDF4\_netCDF4.pyx in netCDF4._netCDF4._ensure_nc_success()
#
# RuntimeError: NetCDF: HDF error

# %% [markdown]
# # AROME

# %%
def read_2D_variables_AROME(variableList, lon, lat, slice_lat_lon=False):
    """ WITH the sel Method
    Read all the 2D variables (single netcdf per variable) and merge them

    :param variableList: List of the selected variables
    :param lon: Longitude of the MOMAA station
    :param lat: Latitude of the MOMAA station
    :param slice_lat_lon: Method for selecting latitude and longitude ('nearest' for nearest neighbor, None for exact match)
    :return: Merged DataFrame with all the variables
    """
    datasets = []  # List to hold the interpolated datasets for each variable

    for variable in variableList:
        file_path = os.path.join(dir_2D_AROME, f"AROME_Geosphere_20171015T1200Z_CAP02_2D_30min_1km_best_{variable}.nc")

        ds = xr.open_dataset(file_path)

        # Use no method if lat or lon are slice objects
        if slice_lat_lon:
            ds = ds.sel(longitude=lon, latitude=lat).isel(time=slice(4, None))
        else:
            ds = ds.sel(longitude=lon, latitude=lat, method="nearest").isel(time=slice(4, None))

        for var, units in variables_units_2D_AROME.items():
            if var in ds:
                ds[var].attrs['units'] = units

        ds_quantified = ds.metpy.quantify()
        datasets.append(ds_quantified)

    return xr.merge(datasets, join="exact")

# %%
def read_3D_variables_AROME(variables, method, lon, lat, slice_lat_lon=False, level=None, time=None):
    """
    Merge datasets for a list of variables at a specific location and time.
    The (lat, lon, time) parameters can also be arrays, e.g., [10, 12, 13].

    :param variables: List of variable names to include in the final merged dataset.
    :param method: Selection method ('sel' or 'interp') for data points.
    :param level: optional nz coordinate for data selection.
    :param lon: Longitude coordinate for data selection.
    :param lat: Latitude coordinate for data selection.
    :param time: Optional time (is set from 4 to None) assuming it starts at 12:00
    :param slice_lat_lon: default False, says if it is a slice object or not
    :return: Merged xarray Dataset for the specified variables, location, and time.
    """
    datasets = []  # List to hold datasets for each variable

    for var in variables:
        # Construct the file path and open the dataset
        file_path = os.path.join(dir_3D_AROME, f"AROME_Geosphere_20171015T1200Z_CAP02_3D_30min_1km_best_{var}.nc")
        ds = xr.open_dataset(file_path)

        if time is None:
            time_start = pd.to_datetime('2017-10-15 14:00:00',
                                        format='%Y-%m-%d %H:%M:%S')
            time_end = pd.to_datetime('2017-10-16 12:00:00',
                                      format='%Y-%m-%d %H:%M:%S')
            time = pd.date_range(start=time_start, end=time_end, freq='30min')

        # Select or interpolate the dataset based on the method
        ds_selected = ds.isel(x=398, y=215)
            
        # Update variable units
        for variable, units in variables_units_3D_AROME.items():
            if variable in ds_selected:
                ds_selected[variable].attrs['units'] = units

        # Quantify the dataset and append to the list
        datasets.append(ds_selected.metpy.quantify())

    # Merge all datasets
    return xr.merge(datasets, join="exact")

# %%
def read_timeSeries_AROME(location):
    """The Timeseries is a direct AROME model output which holds all variables (see Data_structure.md) for a specific
    location
    ::param location: is the selected location
    """
    pattern = f"AROME_Geosphere_20171015T1200Z_{location}_timeseries_40s_*.nc"
    final_path_pattern = os.path.join(dir_timeseries_AROME, pattern)
    # Use glob to find files that match the pattern
    matching_files = glob.glob(final_path_pattern)

    # Assuming there's only one match per location, open the dataset
    if matching_files:
        return xr.open_dataset(matching_files[0])
    else:
        raise FileNotFoundError(f"No files found for location {location}")

# %%
def read_in_arome(time, method, lon, lat):
    my_variable_list = ["p", "q", "th", "u", "v", "z"]

    if (method == "sel") | (method == "interp"):
        print(f"Your selected method is {method}")
    else:
        raise AttributeError(
            "You have to define a method (sel or interp) how the point near the LOWI should be selected")

    df_final = read_3D_variables_AROME(variables=my_variable_list, method=method, lon=lon, lat=lat, time=time)
    return df_final

# %%
def read_in_arome(time, method, lon, lat):
    """plot the MODEL output of AROME as it would be a Radiosonde"""
    my_variable_list = ["p", "q", "th", "u", "v", "z"]

    if (method == "sel") | (method == "interp"):
        print(f"Your selected method is {method}")
    else:
        raise AttributeError(
            "You have to define a method (sel or interp) how the point near the LOWI should be selected")

    df_final = read_3D_variables_AROME(variables=my_variable_list, method=method, lon=lon, lat=lat, time=time)

    print(df_final["p"].metpy.unit_array.magnitude) 
    #Extract values
    df_final["temperature"] = metpy.calc.temperature_from_potential_temperature(df_final["p"], df_final["th"])
    p = df_final["p"].metpy.unit_array.to(units.hPa)  # Metadata is removed
    T = df_final["temperature"].metpy.unit_array.to(units.degC)

    ds = xr.Dataset()

    return df_final

# %%
arome = read_in_arome(time=all, method='sel', lon=11.384167, lat=47.259998)
arome
# Out:
# Your selected method is sel
# [[  604.0626  3191.4956  4343.409  ... 95455.516  95593.64   95715.29  ]
#  [  604.0626  3191.4956  4343.409  ... 95091.37   95229.04   95350.164 ]
#  [  604.0626  3191.4956  4343.409  ... 95056.92   95194.586  95316.7   ]
#  ...
#  [  604.0626  3191.4956  4343.409  ... 95159.84   95297.56   95418.734 ]
#  [  604.0626  3191.4956  4343.409  ... 95141.25   95278.97   95400.14  ]
#  [  604.0626  3191.4956  4343.409  ... 95114.16   95251.875  95373.04  ]]
# <xarray.Dataset> Size: 142kB
# Dimensions:      (record: 49, level: 90)
# Dimensions without coordinates: record, level
# Data variables:
#     p            (record, level) float32 18kB <Quantity([[  604.0626  3191.49...
#     longitude    (record) float32 196B <Quantity([11.385 11.385 11.385 11.385...
#     latitude     (record) float32 196B <Quantity([47.255 47.255 47.255 47.255...
#     nz           (record, level) float32 18kB <Quantity([[ 1.  2.  3. ... 88....
#     time         (record) datetime64[ns] 392B 2017-10-15T12:00:00 ... 2017-10...
#     q            (record, level) float32 18kB <Quantity([[3.0404235e-06 3.072...
#     th           (record, level) float32 18kB <Quantity([[991.32324 565.86816...
#     u            (record, level) float32 18kB <Quantity([[20.367996    1.3705...
#     v            (record, level) float32 18kB <Quantity([[ 2.43911028e-01 -2....
#     z            (record, level) float32 18kB <Quantity([[34289.793   23467.7...
#     temperature  (record, level) float32 18kB <Quantity([[230.27069 211.48766...
# Attributes:
#     NCO:          netCDF Operators version 4.9.7 (Homepage = http://nco.sf.ne...
#     history:      created by B. Wibmer on 2023-11-29 12:32:16
#     description:  AROME model output for TEAMx CAP model intercomparison study
#     institution:  GeoSphere Austria and ACINN (University of Innsbruck, Austria)

# %%
#max
temp = np.zeros(len(arome.temperature))
for i in range(len(arome.temperature)):
    temp[i] = (arome.temperature[i][76].values)
temp.size
#Hafelekar
temp_seg = np.zeros(len(arome.temperature))
for i in range(len(arome.temperature)):
    temp_seg[i] = (arome.temperature[i][52].values)
temp_seg
# Out:
# array([285.03085327, 285.12185669, 285.12112427, 285.09042358,
#        285.03567505, 285.08084106, 284.9708252 , 284.94039917,
#        284.9755249 , 284.88336182, 284.80014038, 284.71435547,
#        284.69403076, 284.69351196, 284.69952393, 284.68304443,
#        284.69091797, 284.71881104, 284.69650269, 284.7059021 ,
#        284.67077637, 284.59768677, 284.49545288, 284.40930176,
#        284.36221313, 284.30548096, 284.2305603 , 284.18081665,
#        284.15328979, 284.11764526, 284.07116699, 284.03100586,
#        283.99575806, 283.98825073, 284.00769043, 284.03689575,
#        284.12121582, 284.27828979, 284.38873291, 284.45651245,
#        284.52471924, 284.62130737, 284.75177002, 284.84036255,
#        284.94241333, 284.98477173, 285.06460571, 285.15353394,
#        285.18057251])

# %% [markdown]
# # UM

# %%
def get_ukmo_level(city_name=None, lat=None, lon=None):
    """read in UKMO Model at a fixed point and select the lowest level, either with city_name or with (lat, lon)"""
    if city_name is not None:
        lat, lon = get_coordinates_by_station_name(city_name)

    xi, yi = get_rotated_index_of_lat_lon(latitude=lat, longitude=lon)

    df = pd.DataFrame()
    for var in ["u", "v", "w", "z", "th", "q", "p"]:
        data = xr.open_dataset(f"{ukmo_folder}/MetUM_MetOffice_20171015T1200Z_CAP02_3D_30min_1km_optimal_{var}.nc")
        dat = data.sel(time=slice("2017-10-15T14:00:00", "2017-10-16T12:00:00.000000000"))
        
        #HERE CHANGE FOR OTHER LEVELS
        data_final = dat.isel(grid_latitude=yi, grid_longitude=xi, model_level_number=5, bnds=1) 

        # print(data_final["level_height"].values) # u and v are on 2.5 m, all other variables at 5m

        if var == "v":
            df["transformed_y_wind"] = data_final["transformed_y_wind"]
            df.set_index(data_final["time"].values, inplace=True)

        elif var == "u":
            df["transformed_x_wind"] = data_final["transformed_x_wind"]

        elif var == "w":
            df["upward_air_velocity"] = data_final["upward_air_velocity"]
        elif var == "z":
            df["geopotential_height"] = data_final["geopotential_height"]
        elif var == "th":
            df["air_potential_temperature"] = data_final["air_potential_temperature"]
        elif var == "q":
            df["specific_humidity"] = data_final["specific_humidity"]
        elif var == "p":
            df["air_pressure"] = data_final["air_pressure"]

    # convert variables
    temp_pot = df["air_potential_temperature"].values * units("K")
    pres = df["air_pressure"].values * units("Pa")

    df["temperature"] = mpcalc.temperature_from_potential_temperature(pres,
                                                                      temp_pot).magnitude - 273.15  # convert it to celsius

    df["specific_humidity"] = df["specific_humidity"] * 1000  # from kg / kg in g/kg
    u_icon = df["transformed_x_wind"].values * units("m/s")
    v_icon = df["transformed_y_wind"].values * units("m/s")

    df["wind_dir"] = mpcalc.wind_direction(u_icon, v_icon, convention='from')
    df["windspeed"] = mpcalc.wind_speed(u_icon, v_icon)

    temp_C = df["temperature"].values * units("degC")

    specific_humidity = df["specific_humidity"].values * units("g/kg")

    df["relative_humidity"] = mpcalc.relative_humidity_from_specific_humidity(pres.to(units.hPa), temp_C.to(units.K),
                                                                              specific_humidity).to("percent")
    return df

# %%
def get_ukmo_level_haf(city_name=None, lat=None, lon=None):
    """read in UKMO Model at a fixed point and select the lowest level, either with city_name or with (lat, lon)"""
    if city_name is not None:
        lat, lon = get_coordinates_by_station_name(city_name)

    xi, yi = get_rotated_index_of_lat_lon(latitude=lat, longitude=lon)

    df = pd.DataFrame()
    for var in ["u", "v", "w", "z", "th", "q", "p"]:
        data = xr.open_dataset(f"{ukmo_folder}/MetUM_MetOffice_20171015T1200Z_CAP02_3D_30min_1km_optimal_{var}.nc")
        dat = data.sel(time=slice("2017-10-15T14:00:00", "2017-10-16T12:00:00.000000000"))
        
        #HERE CHANGE FOR OTHER LEVELS
        data_final = dat.isel(grid_latitude=yi, grid_longitude=xi, model_level_number=21, bnds=1) 

        # print(data_final["level_height"].values) # u and v are on 2.5 m, all other variables at 5m

        if var == "v":
            df["transformed_y_wind"] = data_final["transformed_y_wind"]
            df.set_index(data_final["time"].values, inplace=True)

        elif var == "u":
            df["transformed_x_wind"] = data_final["transformed_x_wind"]

        elif var == "w":
            df["upward_air_velocity"] = data_final["upward_air_velocity"]
        elif var == "z":
            df["geopotential_height"] = data_final["geopotential_height"]
        elif var == "th":
            df["air_potential_temperature"] = data_final["air_potential_temperature"]
        elif var == "q":
            df["specific_humidity"] = data_final["specific_humidity"]
        elif var == "p":
            df["air_pressure"] = data_final["air_pressure"]

    # convert variables
    temp_pot = df["air_potential_temperature"].values * units("K")
    pres = df["air_pressure"].values * units("Pa")

    df["temperature"] = mpcalc.temperature_from_potential_temperature(pres,
                                                                      temp_pot).magnitude - 273.15  # convert it to celsius

    df["specific_humidity"] = df["specific_humidity"] * 1000  # from kg / kg in g/kg
    u_icon = df["transformed_x_wind"].values * units("m/s")
    v_icon = df["transformed_y_wind"].values * units("m/s")

    df["wind_dir"] = mpcalc.wind_direction(u_icon, v_icon, convention='from')
    df["windspeed"] = mpcalc.wind_speed(u_icon, v_icon)

    temp_C = df["temperature"].values * units("degC")

    specific_humidity = df["specific_humidity"].values * units("g/kg")

    df["relative_humidity"] = mpcalc.relative_humidity_from_specific_humidity(pres.to(units.hPa), temp_C.to(units.K),
                                                                              specific_humidity).to("percent")
    return df

# %%
um_lowest_level = get_ukmo_level(lat=47.2598, lon=11.3553) #LOWI
um_seg = get_ukmo_level_haf(lat=47.2598, lon=11.3553) #LOWI
um_lowest_level
# Out:
#                      transformed_x_wind  transformed_y_wind  \
# 2017-10-15 14:00:00            0.562470            0.437791
# 2017-10-15 14:30:00           -0.374936           -0.125195
# 2017-10-15 15:00:00           -0.687952           -0.250358
# 2017-10-15 15:30:00           -0.750159            0.312108
# 2017-10-15 16:00:00           -0.625482            0.187170
# 2017-10-15 16:30:00           -0.625869            0.187173
# 2017-10-15 17:00:00           -0.812466            0.312076
# 2017-10-15 17:30:00           -1.312434            0.249318
# 2017-10-15 18:00:00           -1.062434            0.249448
# 2017-10-15 18:30:00           -1.312338            0.061819
# 2017-10-15 19:00:00           -1.687693           -0.000874
# 2017-10-15 19:30:00           -1.375095            0.186793
# 2017-10-15 20:00:00           -0.875064            0.124552
# 2017-10-15 20:30:00            0.437661            0.062723
# 2017-10-15 21:00:00            1.250064           -0.124353
# 2017-10-15 21:30:00            0.937147            0.312989
# 2017-10-15 22:00:00            1.000613            0.313012
# 2017-10-15 22:30:00            1.501291            0.500767
# 2017-10-15 23:00:00            1.501259            0.563272
# 2017-10-15 23:30:00            0.500550            0.437752
# 2017-10-16 00:00:00           -0.563012            0.624704
# 2017-10-16 00:30:00           -0.125159            0.312427
# 2017-10-16 01:00:00            0.187821           -0.249909
# 2017-10-15 15:30:00          35.885326
# 2017-10-15 16:00:00          37.501385
# 2017-10-15 16:30:00          37.746185
# 2017-10-15 17:00:00          36.417969
# 2017-10-15 17:30:00          37.756077
# 2017-10-15 18:00:00          37.783688
# 2017-10-15 18:30:00          36.988247
# 2017-10-15 19:00:00          38.884602
# 2017-10-15 19:30:00          38.267853
# 2017-10-15 20:00:00          38.242535
# 2017-10-15 20:30:00          39.006699
# 2017-10-15 21:00:00          40.067883
# 2017-10-15 21:30:00          40.138531
# 2017-10-15 22:00:00          40.268768
# 2017-10-15 22:30:00          39.436993
# 2017-10-15 23:00:00          39.337109
# 2017-10-15 23:30:00          39.082001
# 2017-10-16 00:00:00          40.045387
# 2017-10-16 00:30:00          38.858154
# 2017-10-16 01:00:00          38.850605
# 2017-10-16 01:30:00          37.686787
# 2017-10-16 02:00:00          37.678665
# 2017-10-16 02:30:00          37.508873
# 2017-10-16 03:00:00          37.151531
# 2017-10-16 03:30:00          37.036510
# 2017-10-16 04:00:00          36.992928
# 2017-10-16 04:30:00          36.893578
# 2017-10-16 05:00:00          36.396309
# 2017-10-16 05:30:00          38.344601
# 2017-10-16 06:00:00          37.486229
# 2017-10-16 06:30:00          37.083042
# 2017-10-16 07:00:00          37.408665
# 2017-10-16 07:30:00          37.482021
# 2017-10-16 08:00:00          36.673374
# 2017-10-16 08:30:00          36.608349
# 2017-10-16 09:00:00          36.377514
# 2017-10-16 09:30:00          35.983028
# 2017-10-16 10:00:00          35.854538
# 2017-10-16 10:30:00          34.417435
# 2017-10-16 11:00:00          32.145809
# 2017-10-16 11:30:00          29.511618
# 2017-10-16 12:00:00          27.920988

# %%
datetime_range = pd.date_range(start='2017-10-15 12:00', end='2017-10-16 11:00', freq='H')

# %% [markdown]
# # PLOTS

# %%
#hobo_zeitreihe = [station_data['ta'] for station_data in read_in_hobos(loc, my_time=datetime_range).values()]

# %%
datetime_range_hobo = pd.date_range(start='2017-10-15 14:00', end='2017-10-16 12:00', freq='H')

# %%
#MAX


plt.plot(arome.time, temp-273.15, c='r', label='AROME', ls=(0, (1, 2)))
plt.plot(wrf.time, temp_wrf, c='b', label='WRF', ls=(0, (5, 2)))
plt.plot(um_lowest_level.index, um_lowest_level.temperature, c='g', label='UM', ls=(0, (5, 2, 1, 2)))
plt.plot(datetime_range, icon, c='orange', label='ICON', ls=(0, (5, 2, 1, 2, 1, 2)))
plt.plot(datetime_range, icon2TE, c='m', label='ICON2TE', ls=(0, (5, 2, 5, 2, 1, 2)))
plt.plot(hatpro_selected_time.rawdate, hatpro_selected_time.T[13], c='tab:blue', label='HATPRO', lw=4)
plt.plot(datetime_range_hobo, hobo_zeitreihe[2], c='y', label='HOBO', lw=4)
plt.vlines(x=sunset, ymin=9, ymax=24, color='k', lw=2, ls='-')
plt.vlines(x=sunrise, ymin=9, ymax=19, color='k', lw=2, ls='-')
plt.text(sunset - pd.Timedelta(hours=1), 24.5, 'Sunset')
plt.text(sunrise - pd.Timedelta(hours=1), 19.5, 'Sunrise')
plt.ylim(9,26)
plt.xticks(rotation=30)
plt.xlabel('Time (UTC)')
plt.ylabel('$T$ (°C)')
plt.legend()
#plt.text(sunrise + pd.Timedelta(hours=4), 25, r'$z_{max}$', fontsize=16)
plt.tight_layout()
plt.grid()
plt.savefig("D:/plots/zeitreihe_max.svg")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17828\812757758.py in <module>
#       3
#       4 plt.plot(arome.time, temp-273.15, c='r', label='AROME', ls=(0, (1, 2)))
# ----> 5 plt.plot(wrf.time, temp_wrf, c='b', label='WRF', ls=(0, (5, 2)))
#       6 plt.plot(um_lowest_level.index, um_lowest_level.temperature, c='g', label='UM', ls=(0, (5, 2, 1, 2)))
#       7 plt.plot(datetime_range, icon, c='orange', label='ICON', ls=(0, (5, 2, 1, 2, 1, 2)))
#
# AttributeError: module 'wrf' has no attribute 'time'

# %%
model = ['HATPRO', 'HOBO', 'WRF','AROME','UM','ICON','ICON2TE']
np.round(pd.DataFrame({'model': model,
                      'T_min': [min(hatpro_selected_time.T[13]).values.item(), min(hobo_zeitreihe[2]), min(temp_wrf), 
                            min(temp-273.15), min(um_lowest_level.temperature), min(icon), min(icon2TE)]
                        }).set_index('model'),2)

# %%
np.mean([min(temp-273.15),
min(temp_wrf),
min(um_lowest_level.temperature),
min(icon),
min(icon2TE)])

# %%
np.mean([min(hatpro_selected_time.T[13]).values.item(), min(hobo_zeitreihe[2])])

# %%
sunset = pd.to_datetime('2017-10-15 16:25:00') #lt schöni in UTC
sunrise = pd.to_datetime('2017-10-16 5:37:00')

# %%
plt.plot(arome.time, temp_seg-273.15, c='r', label='AROME', ls=(0, (1, 2)))
plt.plot(wrf.time, temp_wrf_seg, c='b', label='WRF', ls=(0, (5, 2)))
plt.plot(um_lowest_level.index, um_seg.temperature, c='g', label='UM', ls=(0, (5, 2, 1, 2)))
plt.plot(datetime_range, icon_seg, c='orange', label='ICON', ls=(0, (5, 2, 1, 2, 1, 2)))
plt.plot(datetime_range, icon2TE_seg, c='m', label='ICON2TE', ls=(0, (5, 2, 5, 2, 1, 2)))
plt.plot(hatpro_selected_time.rawdate, hatpro_selected_time.T[22], c='tab:blue', label='HATPRO', lw=4)
plt.plot(datetime_range_hobo, hobo_zeitreihe[0], c='y', label='HOBO', lw=4)
plt.vlines(x=sunset, ymin=5.5, ymax=15, color='k', lw=2, ls='-')
plt.vlines(x=sunrise, ymin=5.5, ymax=13, color='k', lw=2, ls='-')
plt.text(sunset - pd.Timedelta(hours=1), 15.25, 'Sunset')
plt.text(sunrise - pd.Timedelta(hours=1), 13.25, 'Sunrise')
plt.ylim(7,16.5)
#plt.vlines(x=pd.to_datetime('2017-10-16 3:00:00'), ymin=5.5, ymax=13, color='k', lw=2, ls='-')

plt.xticks(rotation=30)
plt.xlabel('Time (UTC)')
plt.ylabel('$T$ (°C)')
plt.legend()
plt.tight_layout()
plt.grid()
plt.savefig("D:/plots/zeitreihe_hafelekar.svg")
